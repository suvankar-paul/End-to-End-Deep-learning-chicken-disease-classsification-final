# %%
print("suvankar")
# Out:
# suvankar

# %%
import boto3

aws_key     = "AKIARZ5BNDO2M2M3Q5U5"
aws_secret  = "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"
bucket      = "chicken48"
file_key    = "data.zip"  # file in bucket
download_to = "data.zip"  # local filename

s3 = boto3.client('s3',
    aws_access_key_id     = aws_key,
    aws_secret_access_key = aws_secret
)

s3.download_file(bucket, file_key, download_to,
                 ExtraArgs={"RequestPayer": "requester"})  # remove if bucket is not requester-payer

print("Downloaded successfully ✔")
# Out:
# Downloaded successfully ✔
